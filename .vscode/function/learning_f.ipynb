# %%
# Don't run this code, it's just an example to memorize "min" and "max".
normal_hours = min(hours_i, 40)
       # Here, "40" is the minimum. If the user types "50", 
       # between those two numbers "40" is the smaller one, 
       # and if the user types "25", the code will use "25" instead of "40".
       
extra_hours = max(hours_i - 40, 0)
       # Here, "0" is the maximum. If the user types "35", 
       # the result will be "-5". Between those two numbers, 
       # "0" is the larger one.
# Out:
# Your total weekly hour is: 20. Your payment will be: 475.00

# %% [markdown]
# ⚠️ If the code has a problem - Ctrl + Shift + P → Developer: Reload Window (It's reload the VS Code without close the folder).

# %%
def greet(lang):
    if lang == "es":
        print("Holla")
    elif lang == "port":
        print("Oi")
    else:
        print("Hello")

greet("port")
# Out:
# Oi

# %%
def greet():
    return("Hello")

print(greet(), "Bobby")
# Out:
# Hello Bobby

# %%
def addthree(a, b, c):
    add = a + b + c
    return add

x = addthree (18, 23, 52)

print(x)
# Out:
# 93
