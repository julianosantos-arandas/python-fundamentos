# %%
try:
    raw_hour = (input("Insert your weekly worked hours: ").strip())
    hour = int(raw_hour)

except ValueError:
    print(f"Error: you typed {raw_hour}, please insert a number")
    raise SystemExit

try:
    raw_rate = (input("Insert your rate: ").strip().replace(",", "."))
    rate = float(raw_rate)

except:
    print(f"Error: you typed {raw_rate}, please insert a number")

else:
    def normal_pay():
     multiple = rate * hour
     return multiple

    if hour > 40:
        overtime_hours = (hour - 40)
        rate_value = (rate * 40) + (overtime_hours * rate * 1.5)
        print(f"Your weekly worked hours are: {hour}. Your weekly payment is: {rate_value:.2f}")

    else:
        print(f"Your weekly worked hours are: {hour}. Your weekly payment is: {normal_pay()}")
# Out:
# Error: you typed d, please insert a number
# Error: you typed d, please insert a number

# %%
try:
    raw_hour = (input("Insert your weekly worked hours: ").strip())
    hour = int(raw_hour)

except ValueError:
    print(f"Error: you typed {raw_hour}, please insert a number")
    raise SystemExit

try:
    raw_rate = (input("Insert your rate: ").strip().replace(",", "."))
    rate = float(raw_rate)

except:
    print(f"Error: you typed {raw_rate}, please insert a number")
    raise SystemExit

def computepay (hr, rt):
    if hr > 40:
        normal_h = hr - 40
        total_h = (rt * 40) + (rate * normal_h * 1.5)
        print(f"Your weekly worked hours are: {hr}. Your weekly payment is: {total_h:.2f}")

    else:
        regular_p = rt * hr
        print(f"Your weekly worked hours are: {hr}. Your weekly payment is: {regular_p}")

computepay(hour, rate)
# Out:
# Error: you typed ç, please insert a number
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
subjects = ["Math", "English", "History"]
note = 0

for list_subjects in subjects:
    add_note = float(input(f"Insert your {list_subjects} note: ").strip().replace(",", "."))
    note += add_note

final_note = note / len(subjects)

def final_notes():
    convert = {final_note >= 9: "A - Approved ✅",
               final_note >= 8: "B - Approved ✅",
               final_note >= 7: "C - Educational Recovery ⚠️",
               final_note >= 6: "D - Failed ❌",
               final_note < 6: "F - Failed ❌"}
    print(f"Your final note is {final_note:.2f}.") 

final_notes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 18
#      11     convert = {final_note >= 9: "A - Approved ✅",
#      12                final_note >= 8: "B - Approved ✅",
#      13                final_note >= 7: "C - Educational Recovery ⚠️",
#      14                final_note >= 6: "D - Failed ❌",
#      15                final_note < 6: "F - Failed ❌"}
#      16     print(f"Your final note is {final_note:.2f}.")
# ---> 18 final_notes()
#
# TypeError: final_notes() missing 1 required positional argument: 'final_note'
